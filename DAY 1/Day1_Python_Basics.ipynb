# %%
#THE CLASSIC
print("HELLO,WORLD!")
print("SRIHARINI")
# Out:
# HELLO,WORLD!
# SRIHARINI

# %%
#ESCAPE ARTIST
print("Aplle\nBanana\nCherry")
# Out:
# Aplle
# Banana
# Cherry

# %%
#THE TABULAR
print("ID\tNAME\tMARK")
# Out:
# ID	NAME	MARK

# %%
#INTEGER ECHO
age=int(input("Enter Your Age:"))
print("You Are",age,"Years Old.")
# Out:
# Enter Your Age: 19
# You Are 19 Years Old.

# %%
#DECIMAL PRECISION
num=float(input("Enter a number:"))
print(f"{num:.2f}")
# Out:
# Enter a number: 2.123
# 2.12

# %%
#CHARACTER CAPTURE
ch=input("Enter a character:")
print("The character is:",ch)
# Out:
# Enter a character: A
# The character is: A

# %%
#THE BOX PRINTER
print("*****")
print("*   *")
print("*   *")
print("*****")
# Out:
# *****
# *   *
# *   *
# *****

# %%
#BIO DATA
RollNumber =int(input("enter your RollNumber:"))
Section=input("enter your Section:")
CGPA=float(input("enter your CGPA:"))
print(f"RollNumber:{RollNumber},Section:{Section},CGPA:{CGPA}")
# Out:
# enter your RollNumber: 29
# enter your Section: B
# enter your CGPA: 8.95
# RollNumber:29,Section:B,CGPA:8.95

# %%
#QUOTE ME
print('sri said,"python is fun"')
# Out:
# sri said,"python is fun"

# %%
#THE MULTI-READER
a,b=map(int,input("Enter two numbers:").split(","))
print("sum=",a+b)
# Out:
# Enter two numbers: 23,56
# sum= 79

# %%
#BASIC SUM
a = int(input("A = "))
b = int(input("B = "))
print("Sum =", a + b)
# Out:
# A =  23
# B =  45
# Sum = 68

# %%
#THE BIG FOUR
a = int(input("A = "))
b = int(input("B = "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# A =  34
# B =  56
# Addition: 90
# Subtraction: -22
# Multiplication: 1904
# Division: 0.6071428571428571

# %%
#THE REMAINDER FINDER
a = int(input("A = "))
b = int(input("B = "))
print("Remainder =", a % b)
# Out:
# A =  45
# B =  89
# Remainder = 45

# %%
#FLOAT DIVISION
a=float(input("A="))
b=float(input("B="))
c=a/b
print(c)
# Out:
# A= 90
# B= 80
# 1.125

# %%
#SQUARE AND CUBE
a = int(input("A = "))
print("Square =", a ** 2)
print("Cube =", a ** 3)
# Out:
# A =  5
# Square = 25
# Cube = 125

# %%
#AVERAGE CLACULATOR
a=int(input("A="))
b=int(input("B="))
c=int(input("C="))
AVERAGE=(a+b+c)/3
print("AVERAGE=",AVERAGE)
# Out:
# A= 20
# B= 40
# C= 60
# AVERAGE= 40.0

# %%
#SALARY CALCULATOR
basic=float(input("ENTER BASIC PAY:"))
hra=basic*0.10
ta=basic*0.05
total_salary=basic+hra+ta
print("Total Salary=",total_salary)
# Out:
# ENTER BASIC PAY: 25000
# Total Salary= 28750.0

# %%
#THE DIGIT CALCULATOR
num=int(input("THE NUMBER IS="))
print("RESULT=",num//10)
# Out:
# THE NUMBER IS= 345
# RESULT= 34

# %%
#LAST DIGIT EXTRACTOR
num=int(input("THE NUMBER IS="))
print("RESULT=",num%10)
# Out:
# THE NUMBER IS= 453
# RESULT= 3

# %%
#MIXED EXPRESSION
a=int(input("a:"))
b=int(input("b:"))
c=int(input("c:"))
d=int(input("d:"))
result=(a+b)*(c/d)
print("RESULT=",result)
# Out:
# a: 1
# b: 2
# c: 3
# d: 4
# RESULT= 2.25
